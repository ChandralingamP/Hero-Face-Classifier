# %%
import numpy as np
import cv2
import matplotlib
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("./TestImage/suriya.jpg")
img.shape
# Out:
# (363, 383, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(gray,cmap = 'gray')

# %%
face_cascade = cv2.CascadeClassifier('opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('opencv/haarcascades/haarcascade_eye.xml')

# %%
face = face_cascade.detectMultiScale(gray,1.3,5)
face
# Out:
# array([[ 84,  79, 154, 154]])

# %%
(x,y,w,h) = face[0]
x,y,w,h
# Out:
# (84, 79, 154, 154)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in face:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+w),(255,0,0),2)
    roi_gray = gray[y:y+h,x:x+w]
    roi_img = img[y:y+h,x:x+w]
    plt.imshow(roi_img)
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_img,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
    plt.figure()
    plt.imshow(face_img,cmap='gray')

# %% [markdown]
# # To clean faces with  single eye

# %%
def get_cropped_img_if_2_eyes(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY) 
    faces = face_cascade.detectMultiScale(gray)
    for (x,y,w,h ) in faces:
        roi_gray = gray[y:y+h,x:x+w]
        roi_color = img[y:y+h,x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
org_img = cv2.imread("./TestImage/suriya.jpg")
plt.imshow(org_img)

# %%
plt.imshow(get_cropped_img_if_2_eyes("./TestImage/suriya.jpg"))

# %%
pathToDataSetDir = "./DataSet/"
pathToCrpDir = "./DataSet/cropped/"

# %%
import os
image_dirs= []
for x in os.scandir(pathToDataSetDir):
    if x.is_dir():
        image_dirs.append(x.path)

# %%
image_dirs
# Out:
# ['./DataSet/ajith',
#  './DataSet/cropped',
#  './DataSet/dhanush',
#  './DataSet/karthi',
#  './DataSet/simbu',
#  './DataSet/suriya',
#  './DataSet/vijay']

# %%
# import shutil
# if os.path.exists(pathToCrpDir):
#     shutil.rmtree(pathToCrpDir)
# os.mkdir(pathToCrpDir)

# %%
# cropImgDirs = []
# HeroFileNameDirs = {}

# for img_dir in image_dirs:
#     hero_name = img_dir.split("/")[-1]
#     count = 1
#     HeroFileNameDirs[hero_name] = []
#     for entry in os.scandir(img_dir):
        
#         roi_color = get_cropped_img_if_2_eyes(entry.path)
#         if roi_color is not None:
#             cropped_folder = pathToCrpDir +"/"+ hero_name 
#             if not os.path.exists(cropped_folder):
#                 os.makedirs(cropped_folder)
#                 cropImgDirs.append(cropped_folder)
#                 print("created folder :", cropped_folder)
                
                
#             HeroFileName = hero_name + str(count) + ".png"
#             HeroFilePath = cropped_folder +'/'+HeroFileName
#             cv2.imwrite(HeroFilePath,roi_color)
#             HeroFileNameDirs[hero_name].append(HeroFilePath)
#             count +=1

# %%
cropImgDirs = []
for x in os.scandir("./DataSet/cropped"):
    if x.is_dir():
        cropImgDirs.append(x.path.replace("\\","/"))
cropImgDirs
# Out:
# ['./DataSet/cropped/ajith',
#  './DataSet/cropped/dhanush',
#  './DataSet/cropped/karthi',
#  './DataSet/cropped/simbu',
#  './DataSet/cropped/suriya',
#  './DataSet/cropped/vijay']

# %% [markdown]
# ## After clean some images manualy

# %%
HeroFileNameDirs = {}
for path in cropImgDirs:
    name = str(path.split("/")[-1])
    lst = []
    for x in os.scandir(path):
        lst.append(x.path.replace("\\","/"))
    HeroFileNameDirs[name] = lst
HeroFileNameDirs
# Out:
# {'ajith': ['./DataSet/cropped/ajith/ajith1.png',
#   './DataSet/cropped/ajith/ajith10.png',
#   './DataSet/cropped/ajith/ajith11.png',
#   './DataSet/cropped/ajith/ajith12.png',
#   './DataSet/cropped/ajith/ajith13.png',
#   './DataSet/cropped/ajith/ajith14.png',
#   './DataSet/cropped/ajith/ajith15.png',
#   './DataSet/cropped/ajith/ajith16.png',
#   './DataSet/cropped/ajith/ajith17.png',
#   './DataSet/cropped/ajith/ajith18.png',
#   './DataSet/cropped/ajith/ajith2.png',
#   './DataSet/cropped/ajith/ajith20.png',
#   './DataSet/cropped/ajith/ajith21.png',
#   './DataSet/cropped/ajith/ajith22.png',
#   './DataSet/cropped/ajith/ajith23.png',
#   './DataSet/cropped/ajith/ajith24.png',
#   './DataSet/cropped/ajith/ajith25.png',
#   './DataSet/cropped/ajith/ajith26.png',
#   './DataSet/cropped/ajith/ajith27.png',
#   './DataSet/cropped/ajith/ajith28.png',
#   './DataSet/cropped/ajith/ajith29.png',
#   './DataSet/cropped/ajith/ajith3.png',
#   './DataSet/cropped/ajith/ajith30.png',
#   './DataSet/cropped/ajith/ajith31.png',
#   './DataSet/cropped/ajith/ajith33.png',
#   './DataSet/cropped/ajith/ajith34.png',
#   './DataSet/cropped/ajith/ajith35.png',
#   './DataSet/cropped/ajith/ajith38.png',
#   './DataSet/cropped/ajith/ajith39.png',
#   './DataSet/cropped/ajith/ajith4.png',
#   './DataSet/cropped/ajith/ajith40.png',
#   './DataSet/cropped/ajith/ajith41.png',
#   './DataSet/cropped/ajith/ajith43.png',
#   './DataSet/cropped/ajith/ajith44.png',
#   './DataSet/cropped/ajith/ajith45.png',
#   './DataSet/cropped/ajith/ajith46.png',
#   './DataSet/cropped/ajith/ajith47.png',
#   './DataSet/cropped/ajith/ajith48.png',
#   './DataSet/cropped/ajith/ajith49.png',
#   './DataSet/cropped/ajith/ajith5.png',
#   './DataSet/cropped/ajith/ajith50.png',
#   './DataSet/cropped/ajith/ajith51.png',
#   './DataSet/cropped/ajith/ajith52.png',
#   './DataSet/cropped/ajith/ajith53.png',
#   './DataSet/cropped/ajith/ajith7.png',
#   './DataSet/cropped/ajith/ajith8.png'],
#  'dhanush': ['./DataSet/cropped/dhanush/dhanush1.png',
#   './DataSet/cropped/dhanush/dhanush10.png',
#   './DataSet/cropped/dhanush/dhanush11.png',
#   './DataSet/cropped/dhanush/dhanush13.png',
#   './DataSet/cropped/dhanush/dhanush14.png',
#   './DataSet/cropped/dhanush/dhanush15.png',
#   './DataSet/cropped/dhanush/dhanush16.png',
#   './DataSet/cropped/dhanush/dhanush17.png',
#   './DataSet/cropped/dhanush/dhanush18.png',
#   './DataSet/cropped/dhanush/dhanush19.png',
#   './DataSet/cropped/dhanush/dhanush21.png',
#   './DataSet/cropped/dhanush/dhanush22.png',
#   './DataSet/cropped/dhanush/dhanush23.png',
#   './DataSet/cropped/dhanush/dhanush24.png',
#   './DataSet/cropped/dhanush/dhanush25.png',
#   './DataSet/cropped/dhanush/dhanush28.png',
#   './DataSet/cropped/dhanush/dhanush29.png',
#   './DataSet/cropped/dhanush/dhanush3.png',
#   './DataSet/cropped/dhanush/dhanush30.png',
#   './DataSet/cropped/dhanush/dhanush31.png',
#   './DataSet/cropped/dhanush/dhanush32.png',
#   './DataSet/cropped/dhanush/dhanush33.png',
#   './DataSet/cropped/dhanush/dhanush34.png',
#   './DataSet/cropped/dhanush/dhanush35.png',
#   './DataSet/cropped/dhanush/dhanush36.png',
#   './DataSet/cropped/dhanush/dhanush37.png',
#   './DataSet/cropped/dhanush/dhanush38.png',
#   './DataSet/cropped/dhanush/dhanush40.png',
#   './DataSet/cropped/dhanush/dhanush42.png',
#   './DataSet/cropped/dhanush/dhanush44.png',
#   './DataSet/cropped/dhanush/dhanush45.png',
#   './DataSet/cropped/dhanush/dhanush46.png',
#   './DataSet/cropped/dhanush/dhanush47.png',
#   './DataSet/cropped/dhanush/dhanush48.png',
#   './DataSet/cropped/dhanush/dhanush49.png',
#   './DataSet/cropped/dhanush/dhanush5.png',
#   './DataSet/cropped/dhanush/dhanush50.png',
#   './DataSet/cropped/dhanush/dhanush51.png',
#   './DataSet/cropped/dhanush/dhanush52.png',
#   './DataSet/cropped/dhanush/dhanush53.png',
#   './DataSet/cropped/dhanush/dhanush55.png',
#   './DataSet/cropped/dhanush/dhanush56.png',
#   './DataSet/cropped/dhanush/dhanush57.png',
#   './DataSet/cropped/dhanush/dhanush59.png',
#   './DataSet/cropped/dhanush/dhanush6.png',
#   './DataSet/cropped/dhanush/dhanush60.png',
#   './DataSet/cropped/dhanush/dhanush61.png',
#   './DataSet/cropped/dhanush/dhanush62.png',
#   './DataSet/cropped/dhanush/dhanush63.png',
#   './DataSet/cropped/dhanush/dhanush65.png',
#   './DataSet/cropped/dhanush/dhanush66.png',
#   './DataSet/cropped/dhanush/dhanush67.png',
#   './DataSet/cropped/dhanush/dhanush68.png',
#   './DataSet/cropped/dhanush/dhanush69.png',
#   './DataSet/cropped/dhanush/dhanush7.png',
#   './DataSet/cropped/dhanush/dhanush8.png',
#   './DataSet/cropped/dhanush/dhanush9.png'],
#  'karthi': ['./DataSet/cropped/karthi/karthi1.png',
#   './DataSet/cropped/karthi/karthi10.png',
#   './DataSet/cropped/karthi/karthi11.png',
#   './DataSet/cropped/karthi/karthi12.png',
#   './DataSet/cropped/karthi/karthi13.png',
#   './DataSet/cropped/karthi/karthi14.png',
#   './DataSet/cropped/karthi/karthi15.png',
#   './DataSet/cropped/karthi/karthi16.png',
#   './DataSet/cropped/karthi/karthi17.png',
#   './DataSet/cropped/karthi/karthi18.png',
#   './DataSet/cropped/karthi/karthi19.png',
#   './DataSet/cropped/karthi/karthi2.png',
#   './DataSet/cropped/karthi/karthi20.png',
#   './DataSet/cropped/karthi/karthi21.png',
#   './DataSet/cropped/karthi/karthi22.png',
#   './DataSet/cropped/karthi/karthi23.png',
#   './DataSet/cropped/karthi/karthi24.png',
#   './DataSet/cropped/karthi/karthi25.png',
#   './DataSet/cropped/karthi/karthi26.png',
#   './DataSet/cropped/karthi/karthi27.png',
#   './DataSet/cropped/karthi/karthi28.png',
#   './DataSet/cropped/karthi/karthi29.png',
#   './DataSet/cropped/karthi/karthi3.png',
#   './DataSet/cropped/karthi/karthi30.png',
#   './DataSet/cropped/karthi/karthi31.png',
#   './DataSet/cropped/karthi/karthi32.png',
#   './DataSet/cropped/karthi/karthi33.png',
#   './DataSet/cropped/karthi/karthi34.png',
#   './DataSet/cropped/karthi/karthi36.png',
#   './DataSet/cropped/karthi/karthi37.png',
#   './DataSet/cropped/karthi/karthi38.png',
#   './DataSet/cropped/karthi/karthi39.png',
#   './DataSet/cropped/karthi/karthi4.png',
#   './DataSet/cropped/karthi/karthi40.png',
#   './DataSet/cropped/karthi/karthi41.png',
#   './DataSet/cropped/karthi/karthi43.png',
#   './DataSet/cropped/karthi/karthi45.png',
#   './DataSet/cropped/karthi/karthi46.png',
#   './DataSet/cropped/karthi/karthi47.png',
#   './DataSet/cropped/karthi/karthi48.png',
#   './DataSet/cropped/karthi/karthi49.png',
#   './DataSet/cropped/karthi/karthi5.png',
#   './DataSet/cropped/karthi/karthi50.png',
#   './DataSet/cropped/karthi/karthi51.png',
#   './DataSet/cropped/karthi/karthi52.png',
#   './DataSet/cropped/karthi/karthi53.png',
#   './DataSet/cropped/karthi/karthi54.png',
#   './DataSet/cropped/karthi/karthi55.png',
#   './DataSet/cropped/karthi/karthi56.png',
#   './DataSet/cropped/karthi/karthi57.png',
#   './DataSet/cropped/karthi/karthi58.png',
#   './DataSet/cropped/karthi/karthi59.png',
#   './DataSet/cropped/karthi/karthi6.png',
#   './DataSet/cropped/karthi/karthi60.png',
#   './DataSet/cropped/karthi/karthi61.png',
#   './DataSet/cropped/karthi/karthi62.png',
#   './DataSet/cropped/karthi/karthi63.png',
#   './DataSet/cropped/karthi/karthi64.png',
#   './DataSet/cropped/karthi/karthi65.png',
#   './DataSet/cropped/karthi/karthi66.png',
#   './DataSet/cropped/karthi/karthi67.png',
#   './DataSet/cropped/karthi/karthi68.png',
#   './DataSet/cropped/karthi/karthi7.png',
#   './DataSet/cropped/karthi/karthi70.png',
#   './DataSet/cropped/karthi/karthi71.png',
#   './DataSet/cropped/karthi/karthi8.png'],
#  'simbu': ['./DataSet/cropped/simbu/simbu1.png',
#   './DataSet/cropped/simbu/simbu10.png',
#   './DataSet/cropped/simbu/simbu11.png',
#   './DataSet/cropped/simbu/simbu12.png',
#   './DataSet/cropped/simbu/simbu13.png',
#   './DataSet/cropped/simbu/simbu14.png',
#   './DataSet/cropped/simbu/simbu15.png',
#   './DataSet/cropped/simbu/simbu16.png',
#   './DataSet/cropped/simbu/simbu17.png',
#   './DataSet/cropped/simbu/simbu18.png',
#   './DataSet/cropped/simbu/simbu19.png',
#   './DataSet/cropped/simbu/simbu2.png',
#   './DataSet/cropped/simbu/simbu21.png',
#   './DataSet/cropped/simbu/simbu23.png',
#   './DataSet/cropped/simbu/simbu26.png',
#   './DataSet/cropped/simbu/simbu27.png',
#   './DataSet/cropped/simbu/simbu28.png',
#   './DataSet/cropped/simbu/simbu29.png',
#   './DataSet/cropped/simbu/simbu3.png',
#   './DataSet/cropped/simbu/simbu30.png',
#   './DataSet/cropped/simbu/simbu31.png',
#   './DataSet/cropped/simbu/simbu32.png',
#   './DataSet/cropped/simbu/simbu33.png',
#   './DataSet/cropped/simbu/simbu34.png',
#   './DataSet/cropped/simbu/simbu35.png',
#   './DataSet/cropped/simbu/simbu36.png',
#   './DataSet/cropped/simbu/simbu38.png',
#   './DataSet/cropped/simbu/simbu39.png',
#   './DataSet/cropped/simbu/simbu4.png',
#   './DataSet/cropped/simbu/simbu40.png',
#   './DataSet/cropped/simbu/simbu41.png',
#   './DataSet/cropped/simbu/simbu43.png',
#   './DataSet/cropped/simbu/simbu44.png',
#   './DataSet/cropped/simbu/simbu46.png',
#   './DataSet/cropped/simbu/simbu49.png',
#   './DataSet/cropped/simbu/simbu5.png',
#   './DataSet/cropped/simbu/simbu52.png',
#   './DataSet/cropped/simbu/simbu53.png',
#   './DataSet/cropped/simbu/simbu54.png',
#   './DataSet/cropped/simbu/simbu55.png',
#   './DataSet/cropped/simbu/simbu57.png',
#   './DataSet/cropped/simbu/simbu58.png',
#   './DataSet/cropped/simbu/simbu59.png',
#   './DataSet/cropped/simbu/simbu6.png',
#   './DataSet/cropped/simbu/simbu60.png',
#   './DataSet/cropped/simbu/simbu61.png',
#   './DataSet/cropped/simbu/simbu63.png',
#   './DataSet/cropped/simbu/simbu64.png',
#   './DataSet/cropped/simbu/simbu7.png',
#   './DataSet/cropped/simbu/simbu8.png',
#   './DataSet/cropped/simbu/simbu9.png'],
#  'suriya': ['./DataSet/cropped/suriya/suriya1.png',
#   './DataSet/cropped/suriya/suriya10.png',
#   './DataSet/cropped/suriya/suriya11.png',
#   './DataSet/cropped/suriya/suriya12.png',
#   './DataSet/cropped/suriya/suriya13.png',
#   './DataSet/cropped/suriya/suriya14.png',
#   './DataSet/cropped/suriya/suriya16.png',
#   './DataSet/cropped/suriya/suriya17.png',
#   './DataSet/cropped/suriya/suriya18.png',
#   './DataSet/cropped/suriya/suriya19.png',
#   './DataSet/cropped/suriya/suriya2.png',
#   './DataSet/cropped/suriya/suriya20.png',
#   './DataSet/cropped/suriya/suriya21.png',
#   './DataSet/cropped/suriya/suriya22.png',
#   './DataSet/cropped/suriya/suriya23.png',
#   './DataSet/cropped/suriya/suriya24.png',
#   './DataSet/cropped/suriya/suriya25.png',
#   './DataSet/cropped/suriya/suriya26.png',
#   './DataSet/cropped/suriya/suriya27.png',
#   './DataSet/cropped/suriya/suriya28.png',
#   './DataSet/cropped/suriya/suriya29.png',
#   './DataSet/cropped/suriya/suriya3.png',
#   './DataSet/cropped/suriya/suriya30.png',
#   './DataSet/cropped/suriya/suriya31.png',
#   './DataSet/cropped/suriya/suriya32.png',
#   './DataSet/cropped/suriya/suriya33.png',
#   './DataSet/cropped/suriya/suriya35.png',
#   './DataSet/cropped/suriya/suriya36.png',
#   './DataSet/cropped/suriya/suriya37.png',
#   './DataSet/cropped/suriya/suriya38.png',
#   './DataSet/cropped/suriya/suriya39.png',
#   './DataSet/cropped/suriya/suriya4.png',
#   './DataSet/cropped/suriya/suriya40.png',
#   './DataSet/cropped/suriya/suriya42.png',
#   './DataSet/cropped/suriya/suriya43.png',
#   './DataSet/cropped/suriya/suriya44.png',
#   './DataSet/cropped/suriya/suriya45.png',
#   './DataSet/cropped/suriya/suriya46.png',
#   './DataSet/cropped/suriya/suriya47.png',
#   './DataSet/cropped/suriya/suriya48.png',
#   './DataSet/cropped/suriya/suriya49.png',
#   './DataSet/cropped/suriya/suriya5.png',
#   './DataSet/cropped/suriya/suriya50.png',
#   './DataSet/cropped/suriya/suriya51.png',
#   './DataSet/cropped/suriya/suriya52.png',
#   './DataSet/cropped/suriya/suriya53.png',
#   './DataSet/cropped/suriya/suriya54.png',
#   './DataSet/cropped/suriya/suriya55.png',
#   './DataSet/cropped/suriya/suriya56.png',
#   './DataSet/cropped/suriya/suriya58.png',
#   './DataSet/cropped/suriya/suriya59.png',
#   './DataSet/cropped/suriya/suriya6.png',
#   './DataSet/cropped/suriya/suriya60.png',
#   './DataSet/cropped/suriya/suriya61.png',
#   './DataSet/cropped/suriya/suriya62.png',
#   './DataSet/cropped/suriya/suriya63.png',
#   './DataSet/cropped/suriya/suriya65.png',
#   './DataSet/cropped/suriya/suriya66.png',
#   './DataSet/cropped/suriya/suriya67.png',
#   './DataSet/cropped/suriya/suriya68.png',
#   './DataSet/cropped/suriya/suriya7.png',
#   './DataSet/cropped/suriya/suriya70.png',
#   './DataSet/cropped/suriya/suriya71.png',
#   './DataSet/cropped/suriya/suriya72.png',
#   './DataSet/cropped/suriya/suriya73.png',
#   './DataSet/cropped/suriya/suriya74.png',
#   './DataSet/cropped/suriya/suriya8.png',
#   './DataSet/cropped/suriya/suriya9.png'],
#  'vijay': ['./DataSet/cropped/vijay/vijay1.png',
#   './DataSet/cropped/vijay/vijay10.png',
#   './DataSet/cropped/vijay/vijay11.png',
#   './DataSet/cropped/vijay/vijay12.png',
#   './DataSet/cropped/vijay/vijay13.png',
#   './DataSet/cropped/vijay/vijay14.png',
#   './DataSet/cropped/vijay/vijay16.png',
#   './DataSet/cropped/vijay/vijay18.png',
#   './DataSet/cropped/vijay/vijay19.png',
#   './DataSet/cropped/vijay/vijay2.png',
#   './DataSet/cropped/vijay/vijay20.png',
#   './DataSet/cropped/vijay/vijay21.png',
#   './DataSet/cropped/vijay/vijay22.png',
#   './DataSet/cropped/vijay/vijay23.png',
#   './DataSet/cropped/vijay/vijay25.png',
#   './DataSet/cropped/vijay/vijay26.png',
#   './DataSet/cropped/vijay/vijay27.png',
#   './DataSet/cropped/vijay/vijay28.png',
#   './DataSet/cropped/vijay/vijay29.png',
#   './DataSet/cropped/vijay/vijay3.png',
#   './DataSet/cropped/vijay/vijay30.png',
#   './DataSet/cropped/vijay/vijay31.png',
#   './DataSet/cropped/vijay/vijay32.png',
#   './DataSet/cropped/vijay/vijay33.png',
#   './DataSet/cropped/vijay/vijay34.png',
#   './DataSet/cropped/vijay/vijay35.png',
#   './DataSet/cropped/vijay/vijay37.png',
#   './DataSet/cropped/vijay/vijay39.png',
#   './DataSet/cropped/vijay/vijay4.png',
#   './DataSet/cropped/vijay/vijay40.png',
#   './DataSet/cropped/vijay/vijay41.png',
#   './DataSet/cropped/vijay/vijay42.png',
#   './DataSet/cropped/vijay/vijay43.png',
#   './DataSet/cropped/vijay/vijay44.png',
#   './DataSet/cropped/vijay/vijay45.png',
#   './DataSet/cropped/vijay/vijay46.png',
#   './DataSet/cropped/vijay/vijay47.png',
#   './DataSet/cropped/vijay/vijay49.png',
#   './DataSet/cropped/vijay/vijay5.png',
#   './DataSet/cropped/vijay/vijay50.png',
#   './DataSet/cropped/vijay/vijay51.png',
#   './DataSet/cropped/vijay/vijay53.png',
#   './DataSet/cropped/vijay/vijay54.png',
#   './DataSet/cropped/vijay/vijay55.png',
#   './DataSet/cropped/vijay/vijay56.png',
#   './DataSet/cropped/vijay/vijay57.png',
#   './DataSet/cropped/vijay/vijay58.png',
#   './DataSet/cropped/vijay/vijay59.png',
#   './DataSet/cropped/vijay/vijay6.png',
#   './DataSet/cropped/vijay/vijay60.png',
#   './DataSet/cropped/vijay/vijay62.png',
#   './DataSet/cropped/vijay/vijay63.png',
#   './DataSet/cropped/vijay/vijay64.png',
#   './DataSet/cropped/vijay/vijay65.png',
#   './DataSet/cropped/vijay/vijay67.png',
#   './DataSet/cropped/vijay/vijay68.png',
#   './DataSet/cropped/vijay/vijay69.png',
#   './DataSet/cropped/vijay/vijay7.png',
#   './DataSet/cropped/vijay/vijay70.png',
#   './DataSet/cropped/vijay/vijay8.png',
#   './DataSet/cropped/vijay/vijay9.png']}

# %% [markdown]
# #wavelet transfrom

# %%
import pywt
def w2d(img, mode ="haar",level = 1):
    imArray = img
    # Datatype conversion
    # Convert to GrayScale
    imArray = cv2.cvtColor(imArray,cv2.COLOR_BGR2GRAY)
    #convert to float 
    imArray = np.float32(imArray)
    imArray /= 255
    # compute coeeficients
    coeffs = pywt.wavedec2(imArray,mode,level=level)
    
    coeffs_H = list(coeffs)
    coeffs_H[0]*=0
    
    #reconstruction
    imArray_H = pywt.waverec2(coeffs_H,mode)
    imArray_H *= 255
    imArray_H = np.uint8(imArray_H)
    return imArray_H

# %%
im_haar = w2d(get_cropped_img_if_2_eyes("./TestImage/suriya.jpg"),'db1',4)
plt.imshow(im_haar,cmap='gray')

# %%
classDict = {}
count = 0
for hero in HeroFileNameDirs.keys():
    classDict[hero] = count
    count +=1
classDict
# Out:
# {'ajith': 0, 'dhanush': 1, 'karthi': 2, 'simbu': 3, 'suriya': 4, 'vijay': 5}

# %%
X,Y = [] ,[]
for heroName , training_images in HeroFileNameDirs.items():
    for training_image in training_images:
        img = cv2.imread(training_image)
        if( img is None) :
            continue
        scalledRawImg = cv2.resize(img,(32,32))
        img_har = w2d(img , 'db1',4)
        scalledImgHar = cv2.resize(img_har,(32,32))
        combinedImg = np.vstack((scalledRawImg.reshape(32*32*3,1),scalledImgHar.reshape(32*32,1)))
        X.append(combinedImg)
        Y.append(classDict[heroName])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
len(X)
# Out:
# 349

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (349, 4096)

# %% [markdown]
#  ## Data cleaning process is Done

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state=5)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.6477272727272727

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.75      0.67         8
#            1       0.83      0.56      0.67        18
#            2       0.57      0.81      0.67        16
#            3       0.80      0.44      0.57         9
#            4       0.56      0.88      0.68        16
#            5       0.77      0.48      0.59        21
#
#     accuracy                           0.65        88
#    macro avg       0.69      0.65      0.64        88
# weighted avg       0.69      0.65      0.64        88

# %% [markdown]
# ### Let's use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.574383
# 1        random_forest    0.356241
# 2  logistic_regression    0.627794
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.6931818181818182

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.38636363636363635

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.7272727272727273

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 6,  0,  0,  1,  0,  1],
#        [ 2, 11,  1,  0,  4,  0],
#        [ 0,  0, 12,  1,  3,  0],
#        [ 1,  0,  0,  6,  1,  1],
#        [ 0,  0,  2,  0, 13,  1],
#        [ 0,  1,  5,  1,  1, 13]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
classDict
# Out:
# {'ajith': 0, 'dhanush': 1, 'karthi': 2, 'simbu': 3, 'suriya': 4, 'vijay': 5}

# %%
# Save Model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\chandralingam\anaconda3\lib\site-packages (1.1.0)
# ['saved_model.pkl']

# %%
# save class dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(classDict))
